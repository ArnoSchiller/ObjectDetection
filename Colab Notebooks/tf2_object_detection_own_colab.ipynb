# %%
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)

# !pip install numpy

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
#"""

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
#"""

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# change to working tensorflow directory on the drive
# %cd '/content/gdrive/My Drive/objectDetection/tf2_API_object_detection/models/research/object_detection/legacy'

# %%
import time, psutil
Start = time.time()- psutil.boot_time()
Left= 12*3600 - Start
print('Time remaining for this session is: ', Left/3600)

# %%
import os
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/objectDetection/tf2_API_object_detection/models/research/slim/'
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/objectDetection/tf2_API_object_detection/models/'
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/objectDetection/tf2_API_object_detection/models/research/'
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/objectDetection/tf2_API_object_detection/models/research/object_detection'

# %%
# !pip install tf_slim 
# !pip install pycocotools

# %%
# %cd ..
# !python model_main_tf2.py --pipeline_config_path='/content/gdrive/My Drive/objectDetection/models/tf_API_data1_v01_2020-11-06/ssd_efficientdet_d0_512x512_coco17_tpu-8.config' \
--train_dir='/content/gdrive/My Drive/objectDetection/models/tf_API_data1_v01_2020-11-06/training/' \ 
--alsologtostderr 

"""
# !python train.py \
  --num_train_steps=10000 \
  --sample_1_of_n_eval_examples=1 \
  --pipeline_config_path='/content/gdrive/My Drive/objectDetection/models/tf_API_data1_v01_2020-11-06/ssd_efficientdet_d0_512x512_coco17_tpu-8.config' \
  --train_dir='/content/gdrive/My Drive/objectDetection/models/tf_API_data1_v01_2020-11-06/training' \
  --alsologtostderr
#"""
